# %% [markdown]
# # Nutritional Fact Analysis of Coffee Shop Menu

# %% [markdown]
# # ☕ Coffee Shop Menu & Nutrition Analysis
#
# A popular coffee shop offers a wide variety of beverages on its menu, along with multiple size and milk choices. As customers become more health-conscious, management wants to **identify and label healthier beverage options**, such as low-calorie or low-fat choices, to support targeted marketing.
#
# ---
#
# ## **🍹 Beverage Categories**
# - Smoothies
# - Coffee
# - Tea
# - Iced Beverages
#
# ---
#
# ## **📏 Available Sizes**
# - Short
# - Tall
# - Grande
# - Venti
#
# ---
#
# ## **🥛 Milk Types (For Dairy-Based Beverages)**
# - Whole milk
# - Low fat (2%) milk
# - No fat milk
# - Soy milk
#
# ---
#
# ## **🎯 Health-Focused Labelling Initiative**
#
# Management has noticed a growing interest in healthier beverages. To help customers choose wisely, they plan to **mark low-calorie or health-friendly beverages** with a special symbol.
#
# ### Example Hypothesis:
# Beverages prepared with **low-fat milk** may be labeled as:
# - “Healthy”
# - “Heart-Healthy”
#
# because they are presumed to contain:
# - Fewer calories
# - Lower total fat
# - Healthier nutritional profile
#
# Similarly, beverages high in:
# - **Protein**
# - **Fat**
# - **Sugar**
#
# can be flagged for additional marketing insights.
#
# ---
#
# ## **📊 Dataset Overview**
#
# Nutritional facts are recorded for **30+ beverages**, considering all combinations of:
# - Beverage type
# - Size
# - Milk choice
#
# ### **Variables in the dataset include:**
# - Calories
# - Total Fat
# - Trans Fat
# - Saturated Fat
# - Sugars
# - Cholesterol
# - Protein
#
# This dataset will help identify patterns, categorize beverages, and plan health-based marketing strategies.

# %% [markdown]
# ![image.png](attachment:ff4024c1-4f38-4e01-9b5b-8a9f8f43c718.png)

# %% [markdown]
# # 🎯 Project Expectations: Nutritional Analysis for Coffee Shop Menu
# *Role: Management Consultant — Data & Nutritional Insights*
#
# As part of this project, you are expected to deliver **three major analytical components** using the nutritional dataset of the coffee shop’s beverages.
#
# ---
#
# # 1️⃣ Exploratory Data Analysis (EDA)
#
# Conduct a comprehensive exploration of the dataset and generate **actionable insights**.
#
# ### ✔ Key Expectations:
# - Compare nutritional values across:
#   - **Beverage Categories** (Coffee, Tea, Smoothies, Iced Beverages)
#   - **Individual Beverages**
#   - **Sizes** (Short, Tall, Grande, Venti)
#   - **Milk Types** (Whole, Low Fat, Nonfat, Soy)
# - Identify:
#   - Which beverages or categories are **high / low in calories**
#   - Which items are **high / low in fat, saturated fat, and trans fat**
#   - Drinks that contain **high protein**
#   - Drinks that are **high in sugar**
#   - Drinks with the **least carbs** or **highest dietary fiber**
# - Reveal patterns such as:
#   - Impact of **size** on calories
#   - Impact of **milk choices** on fat, sugar, protein
#   - Which beverages are inherently healthier
# - Provide **graphs/tables** wherever required (boxplots, bar charts, heatmaps, distributions)
#
# The goal is to produce **as many insights as possible** to guide menu labeling and marketing decisions.
#
# ---
#
# # 2️⃣ Hypothesis Testing
#
# Management believes that **low-fat milk** results in:
# - Lower calories
# - Lower total fat
#
# And therefore beverages using low-fat milk should be marked as **healthy / heart-healthy**.
#
# ### ✔ Your Task:
# - Formally test the hypothesis using **ANOVA** or **t-tests**:
#   - Compare **calories** across milk types
#   - Compare **total fat** across milk types
# - Determine if low-fat milk **truly leads to significantly lower values**.
# - Report:
#   - Null and alternative hypotheses
#   - Test used and justification
#   - p-values and conclusions
#   - Practical interpretation for management
#
# ### 🎯 Expected Outcome:
# A statistically sound recommendation on whether beverages with **low-fat milk** should be labeled as healthier.
#
# ---
#
# # 3️⃣ Linear Regression Analysis
#
# Management wants a simple model to **predict calories** for new menu items.
#
# ### ✔ Your Task:
# Build a **multiple linear regression model** to predict calories using variables such as:
# - Fat
# - Protein
# - Sugar
# - Carbs
# - Dietary fiber
# - Category, size, milk type (encoded as needed)
#
# ### ✔ Deliverables:
# - Build and validate a **linear regression model**
# - Identify the **most influential predictors**
# - Provide:
#   - Model equation
#   - Coefficient interpretations
#   - R-squared and error metrics
# - Ensure the model is **simple enough** for non-technical staff and future menu additions.
#
# ### 🎯 Expected Outcome:
# A practical, easy-to-use calorie prediction model for new beverages.
#
# ---
#
# # 📌 Summary of Deliverables
#
# | Analysis Type | What You Deliver |
# |---------------|------------------|
# | **EDA** | Insights on calories, fat, sugar, protein, carbs, fiber across beverage attributes |
# | **Hypothesis Testing** | Statistical conclusion on whether low-fat milk leads to healthier beverages |
# | **Regression** | Predictive linear model for calorie estimation |
#
# ---

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"P2_92_DS_NUTRITIONAL_FACT_ANALYSIS_OF_COFFEE_SHOP_MENU.csv")
df.head()
# Out:
#                   Category       Beverage    Size         Milk  Calories  \
# 0                   Coffee  Brewed Coffee   Short          NaN         3
# 1                   Coffee  Brewed Coffee    Tall          NaN         4
# 2                   Coffee  Brewed Coffee  Grande          NaN         5
# 3                   Coffee  Brewed Coffee   Venti          NaN         5
# 4  Classic Espresso Drinks    Caffe Latte   Short  Nonfat Milk        70
#
#    TotalFat  TransFat  SaturatedFat  Sodium  TotalCarb  Cholesterol  \
# 0       0.1       0.0           0.0       0          5            0
# 1       0.1       0.0           0.0       0         10            0
# 2       0.1       0.0           0.0       0         10            0
# 3       0.1       0.0           0.0       0         10            0
# 4       0.1       0.1           0.0       5         75           10
#
#    DietaryFibre  Sugars  Protein
# 0             0       0      0.3
# 1             0       0      0.5
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Beverage', 'Size', 'Milk', 'Calories', 'TotalFat',
#        'TransFat', 'SaturatedFat', 'Sodium', 'TotalCarb', 'Cholesterol',
#        'DietaryFibre', 'Sugars', 'Protein'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Category         object
# Beverage         object
# Size             object
# Milk             object
# Calories          int64
# TotalFat        float64
# TransFat        float64
# SaturatedFat    float64
# Sodium            int64
# TotalCarb         int64
# Cholesterol       int64
# DietaryFibre      int64
# Sugars            int64
# Protein         float64
# dtype: object

# %% [markdown]
# -- 4 variation in the overall dataset - 'Category', 'Beverage', 'Size', 'Milk'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      238 non-null    object
#  1   Beverage      238 non-null    object
#  2   Size          238 non-null    object
#  3   Milk          211 non-null    object
#  4   Calories      238 non-null    int64
#  5   TotalFat      238 non-null    float64
#  6   TransFat      238 non-null    float64
#  7   SaturatedFat  238 non-null    float64
#  8   Sodium        238 non-null    int64
#  9   TotalCarb     238 non-null    int64
#  10  Cholesterol   238 non-null    int64
#  11  DietaryFibre  238 non-null    int64
#  12  Sugars        238 non-null    int64
#  13  Protein       238 non-null    float64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 26.2+ KB

# %%
df.shape
# Out:
# (238, 14)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=238, step=1)

# %%
df.describe()
# Out:
#          Calories    TotalFat    TransFat  SaturatedFat      Sodium  \
# count  238.000000  238.000000  238.000000    238.000000  238.000000
# mean   193.810924    2.931933    1.318908      0.037815    6.407563
# std    103.668135    2.956133    1.648097      0.071737    8.679348
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%    120.000000    0.200000    0.100000      0.000000    0.000000
# 50%    185.000000    2.500000    0.500000      0.000000    5.000000
# 75%    260.000000    4.500000    2.000000      0.100000   10.000000
# max    510.000000   15.000000    9.000000      0.300000   40.000000
#
#         TotalCarb  Cholesterol  DietaryFibre      Sugars     Protein
# count  238.000000   238.000000    238.000000  238.000000  238.000000
# mean   128.067227    35.878151      0.815126   32.819328    7.032773
# std     82.656396    20.927388      1.455189   19.838082    4.893173
# min      0.000000     0.000000      0.000000    0.000000    0.000000
# ...

# %%
df.describe(include='object')
# Out:
#                        Category  \
# count                       238
# unique                        9
# top     Classic Espresso Drinks
# freq                         58
#
#                                               Beverage    Size         Milk
# count                                              238     238          211
# unique                                              32       6            4
# top     Tazo Full-Leaf Red Tea Latte (Vanilla Rooibos)  Grande  Nonfat Milk
# freq                                                12      72           81

# %%
df.Category.unique()
# Out:
# array(['Coffee', 'Classic Espresso Drinks', 'Signature Espresso Drinks',
#        'Tazo Tea Drinks', 'Shaken Iced Beverages', 'Smoothies',
#        'Frappuccino Blended Coffee', 'Frappuccino Light Blended Coffee',
#        'Frappuccino Blended Creme'], dtype=object)

# %%
df.Size.unique()
# Out:
# array(['Short', 'Tall', 'Grande', 'Venti', 'Single', 'Double'],
#       dtype=object)

# %%
df.Milk.unique()
# Out:
# array([nan, 'Nonfat Milk', '2% Milk', 'Soymilk', 'Whole Milk'],
#       dtype=object)

# %%
df.Beverage.unique()
# Out:
# array(['Brewed Coffee', 'Caffe Latte',
#        'Caffe Mocha (Without Whipped Cream)',
#        'Vanilla Latte (Or Other Flavoured Latte)', 'Caffe Americano',
#        'Cappuccino', 'Espresso', 'Skinny Latte (Any Flavour)',
#        'Caramel Macchiato',
#        'White Chocolate Mocha (Without Whipped Cream)',
#        'Hot Chocolate (Without Whipped Cream)',
#        'Caramel Apple Spice (Without Whipped Cream)', 'Tazo Tea',
#        'Tazo Chai Tea Latte', 'Tazo Green Tea Latte',
#        'Tazo Full-Leaf Tea Latte',
#        'Tazo Full-Leaf Red Tea Latte (Vanilla Rooibos)',
#        'Iced Brewed Coffee (With Classic Syrup)',
#        'Iced Brewed Coffee (With Milk & Classic Syrup)',
#        'Shaken Iced Tazo Tea (With Classic Syrup)',
#        'Shaken Iced Tazo Tea Lemonade (With Classic Syrup)',
#        'Banana Chocolate Smoothie', 'Orange Mango Banana Smoothie',
#        'Strawberry Banana Smoothie', 'Coffee',
# ...

# %%
df.groupby('Category')['Size'].unique()
# Out:
# Category
# Classic Espresso Drinks             [Short, Tall, Grande, Venti, Single, Double]
# Coffee                                              [Short, Tall, Grande, Venti]
# Frappuccino Blended Coffee                                 [Tall, Grande, Venti]
# Frappuccino Blended Creme                                  [Tall, Grande, Venti]
# Frappuccino Light Blended Coffee                           [Tall, Grande, Venti]
# Shaken Iced Beverages                                      [Tall, Grande, Venti]
# Signature Espresso Drinks                           [Short, Tall, Grande, Venti]
# Smoothies                                                               [Grande]
# Tazo Tea Drinks                                     [Short, Tall, Grande, Venti]
# Name: Size, dtype: object

# %% [markdown]
# -- Only "Classic Espresso Drinks" Category has "Single, Double"

# %%
df.isnull().sum()
# Out:
# Category         0
# Beverage         0
# Size             0
# Milk            27
# Calories         0
# TotalFat         0
# TransFat         0
# SaturatedFat     0
# Sodium           0
# TotalCarb        0
# Cholesterol      0
# DietaryFibre     0
# Sugars           0
# Protein          0
# dtype: int64

# %%
df.loc[df['Milk'].isnull()]
# Out:
#                       Category  \
# 0                       Coffee
# 1                       Coffee
# 2                       Coffee
# 3                       Coffee
# 40     Classic Espresso Drinks
# 41     Classic Espresso Drinks
# 42     Classic Espresso Drinks
# 43     Classic Espresso Drinks
# 56     Classic Espresso Drinks
# 57     Classic Espresso Drinks
# 98   Signature Espresso Drinks
# 99   Signature Espresso Drinks
# 100  Signature Espresso Drinks
# 101  Signature Espresso Drinks
# 102            Tazo Tea Drinks
# 103            Tazo Tea Drinks
# 104            Tazo Tea Drinks
# 105            Tazo Tea Drinks
# 154      Shaken Iced Beverages
# 155      Shaken Iced Beverages
# 156      Shaken Iced Beverages
# 166      Shaken Iced Beverages
# 167      Shaken Iced Beverages
# 168      Shaken Iced Beverages
# 169      Shaken Iced Beverages
# 170      Shaken Iced Beverages
# 171      Shaken Iced Beverages
#
# ...

# %%
df.loc[df['Milk'].isnull()].Beverage.unique()
# Out:
# array(['Brewed Coffee', 'Caffe Americano', 'Espresso',
#        'Caramel Apple Spice (Without Whipped Cream)', 'Tazo Tea',
#        'Iced Brewed Coffee (With Classic Syrup)',
#        'Shaken Iced Tazo Tea (With Classic Syrup)',
#        'Shaken Iced Tazo Tea Lemonade (With Classic Syrup)'], dtype=object)

# %% [markdown]
# -- After looking at the data and anlyzing these Beverage, it is known thta they dont use Milk in them.

# %%
df.head()
# Out:
#                   Category       Beverage    Size         Milk  Calories  \
# 0                   Coffee  Brewed Coffee   Short          NaN         3
# 1                   Coffee  Brewed Coffee    Tall          NaN         4
# 2                   Coffee  Brewed Coffee  Grande          NaN         5
# 3                   Coffee  Brewed Coffee   Venti          NaN         5
# 4  Classic Espresso Drinks    Caffe Latte   Short  Nonfat Milk        70
#
#    TotalFat  TransFat  SaturatedFat  Sodium  TotalCarb  Cholesterol  \
# 0       0.1       0.0           0.0       0          5            0
# 1       0.1       0.0           0.0       0         10            0
# 2       0.1       0.0           0.0       0         10            0
# 3       0.1       0.0           0.0       0         10            0
# 4       0.1       0.1           0.0       5         75           10
#
#    DietaryFibre  Sugars  Protein
# 0             0       0      0.3
# 1             0       0      0.5
# ...

# %% [markdown]
# Q) Which Beverage has more number of variations?

# %%
df.Beverage.value_counts()
# Out:
# Beverage
# Tazo Full-Leaf Red Tea Latte (Vanilla Rooibos)        12
# Caffe Latte                                           12
# Caffe Mocha (Without Whipped Cream)                   12
# Vanilla Latte (Or Other Flavoured Latte)              12
# Cappuccino                                            12
# Caramel Macchiato                                     12
# White Chocolate Mocha (Without Whipped Cream)         12
# Hot Chocolate (Without Whipped Cream)                 12
# Coffee                                                12
# Tazo Chai Tea Latte                                   12
# Tazo Green Tea Latte                                  12
# Tazo Full-Leaf Tea Latte                              12
# Java Chip (Without Whipped Cream)                      9
# Caramel (Without Whipped Cream)                        9
# Mocha (Without Whipped Cream)                          9
# Iced Brewed Coffee (With Milk & Classic Syrup)         9
# ...

# %% [markdown]
# Q) Which Category has more # of Beverages?

# %%
df.groupby('Category')['Beverage'].nunique().sort_values(ascending=False)
# Out:
# Category
# Classic Espresso Drinks             7
# Tazo Tea Drinks                     5
# Frappuccino Blended Coffee          4
# Frappuccino Light Blended Coffee    4
# Shaken Iced Beverages               4
# Signature Espresso Drinks           4
# Smoothies                           3
# Coffee                              1
# Frappuccino Blended Creme           1
# Name: Beverage, dtype: int64

# %% [markdown]
# ---
#
# # 🔍 Numerical vs Categorical Variable Analysis
#
# To understand the nutritional differences across beverages, sizes, and milk types, we will analyze each **numeric** nutrition variable against multiple **categorical** attributes in the dataset.
#
# ---
#
# ## **📊 Numeric Columns (Nutritional Values)**
#
# We will analyze the following numeric variables:
#
# - **Calories**
# - **TotalFat**
# - **TransFat**
# - **SaturatedFat**
# - **Sodium**
# - **TotalCarb**
# - **Cholesterol**
# - **DietaryFibre**
# - **Sugars**
# - **Protein**
#
# ---
#
# ## **🏷 Categorical Columns (Beverage Attributes)**
#
# Each numeric variable will be compared across the following categorical factors:
#
# - **Category**
#   (e.g., Coffee, Tea, Smoothies, Iced Beverages)
#
# - **Beverage**
#   (specific drink names)
#
# - **Size**
#   (Short, Tall, Grande, Venti)
#
# - **Milk**
#   (Whole Milk, Low Fat, Nonfat, Soy Milk)
#
# ---
#
# ## **📈 Goal of the Analysis**
#
# By analyzing the relationship between **numerical nutritional values** and **categorical beverage attributes**, we aim to:
#
# - Identify **healthier options**
# - Compare nutrient differences **across sizes**
# - Understand how **milk choices** impact calories and fat
# - Compare nutrition across **beverage categories**
# - Support **health-conscious labeling** and **menu optimization**
#
# ---
#
# ## 🔜 Next Steps
#
# You can now proceed to:
# - Perform **groupby summaries**
# - Create **boxplots**, **violin plots**, or **bar charts**
# - Identify **outliers** and **patterns**
# - Build **health labels** (e.g., low calorie, high protein, low fat)
#
# ---

# %% [markdown]
# # 1️⃣ Exploratory Data Analysis (EDA)
#
# Conduct a comprehensive exploration of the dataset and generate **actionable insights**.
#
# ### ✔ Key Expectations:
# - Compare nutritional values across:
#   - **Beverage Categories** (Coffee, Tea, Smoothies, Iced Beverages)
#   - **Individual Beverages**
#   - **Sizes** (Short, Tall, Grande, Venti)
#   - **Milk Types** (Whole, Low Fat, Nonfat, Soy)
# - Identify:
#   - Which beverages or categories are **high / low in calories**
#   - Which items are **high / low in fat, saturated fat, and trans fat**
#   - Drinks that contain **high protein**
#   - Drinks that are **high in sugar**
#   - Drinks with the **least carbs** or **highest dietary fiber**
# - Reveal patterns such as:
#   - Impact of **size** on calories
#   - Impact of **milk choices** on fat, sugar, protein
#   - Which beverages are inherently healthier
# - Provide **graphs/tables** wherever required (boxplots, bar charts, heatmaps, distributions)
#
# The goal is to produce **as many insights as possible** to guide menu labeling and marketing decisions.
#
# ---

# %%
df.head()
# Out:
#                   Category       Beverage    Size         Milk  Calories  \
# 0                   Coffee  Brewed Coffee   Short          NaN         3
# 1                   Coffee  Brewed Coffee    Tall          NaN         4
# 2                   Coffee  Brewed Coffee  Grande          NaN         5
# 3                   Coffee  Brewed Coffee   Venti          NaN         5
# 4  Classic Espresso Drinks    Caffe Latte   Short  Nonfat Milk        70
#
#    TotalFat  TransFat  SaturatedFat  Sodium  TotalCarb  Cholesterol  \
# 0       0.1       0.0           0.0       0          5            0
# 1       0.1       0.0           0.0       0         10            0
# 2       0.1       0.0           0.0       0         10            0
# 3       0.1       0.0           0.0       0         10            0
# 4       0.1       0.1           0.0       5         75           10
#
#    DietaryFibre  Sugars  Protein
# 0             0       0      0.3
# 1             0       0      0.5
# ...

# %% [markdown]
# #### Calories

# %% [markdown]
# Q) Which Category has high Protein, Low protein.

# %%
df.groupby('Category')['Calories'].mean().sort_values()
# Out:
# Category
# Coffee                                4.250000
# Shaken Iced Beverages               114.444444
# Classic Espresso Drinks             140.172414
# Frappuccino Light Blended Coffee    162.500000
# Tazo Tea Drinks                     177.307692
# Frappuccino Blended Creme           248.888889
# Signature Espresso Drinks           250.000000
# Frappuccino Blended Coffee          276.944444
# Smoothies                           282.222222
# Name: Calories, dtype: float64

# %%
x1 = df.groupby('Category')['Calories'].mean().sort_values()
plt.plot(x1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Q) Which Category, Beverage combo has high Protein, Low protein.

# %%
df.groupby(['Category','Beverage'])['Calories'].mean().sort_values()
# Out:
# Category                          Beverage
# Tazo Tea Drinks                   Tazo Tea                                                0.000000
# Coffee                            Brewed Coffee                                           4.250000
# Classic Espresso Drinks           Espresso                                                7.500000
#                                   Caffe Americano                                        13.750000
# Shaken Iced Beverages             Shaken Iced Tazo Tea (With Classic Syrup)              86.666667
# Classic Espresso Drinks           Cappuccino                                             90.000000
# Shaken Iced Beverages             Iced Brewed Coffee (With Classic Syrup)                93.333333
# Classic Espresso Drinks           Skinny Latte (Any Flavour)                            110.000000
# Shaken Iced Beverages             Iced Brewed Coffee (With Milk & Classic Syrup)        122.222222
# ...

# %% [markdown]
# -- No better Insights from it

# %% [markdown]
# Q) Which Category, Size combo has high Protein, Low protein.

# %%
df.groupby(['Category','Size'])['Calories'].mean().sort_values()
# Out:
# Category                          Size
# Coffee                            Short       3.000000
#                                   Tall        4.000000
# Classic Espresso Drinks           Single      5.000000
# Coffee                            Grande      5.000000
#                                   Venti       5.000000
# Classic Espresso Drinks           Double     10.000000
# Shaken Iced Beverages             Tall       78.333333
# Classic Espresso Drinks           Short      83.928571
# Tazo Tea Drinks                   Short      97.692308
# Shaken Iced Beverages             Grande    106.666667
# Frappuccino Light Blended Coffee  Tall      112.500000
# Classic Espresso Drinks           Tall      125.000000
# Signature Espresso Drinks         Short     143.000000
# Tazo Tea Drinks                   Tall      153.076923
# Shaken Iced Beverages             Venti     158.333333
# Frappuccino Light Blended Coffee  Grande    160.000000
# ...

# %% [markdown]
# -- Need to dive deep more, no much clarity insight here

# %% [markdown]
# Q) Which Category, Milk combo has high Protein, Low protein.

# %%
df.groupby(['Category','Milk'])['Calories'].mean().sort_values()
# Out:
# Category                          Milk
# Shaken Iced Beverages             Nonfat Milk    116.666667
#                                   Soymilk        120.000000
#                                   2% Milk        130.000000
# Classic Espresso Drinks           Nonfat Milk    134.500000
#                                   Soymilk        151.250000
# Frappuccino Light Blended Coffee  Nonfat Milk    162.500000
# Tazo Tea Drinks                   Nonfat Milk    175.625000
# Classic Espresso Drinks           2% Milk        184.375000
# Tazo Tea Drinks                   Soymilk        188.750000
#                                   2% Milk        211.875000
# Signature Espresso Drinks         Nonfat Milk    233.333333
# Frappuccino Blended Creme         Nonfat Milk    236.666667
# Signature Espresso Drinks         Soymilk        241.666667
# Frappuccino Blended Creme         Soymilk        243.333333
#                                   Whole Milk     266.666667
# ...

# %% [markdown]
# -- Need to dive deep more, no much clarity insight here

# %% [markdown]
# Q) Size has any relation with Calories?

# %%
x2 = df.groupby(['Size'])['Calories'].mean().sort_values()
x2
# Out:
# Size
# Single      5.000000
# Double     10.000000
# Short     102.052632
# Tall      153.238095
# Grande    215.972222
# Venti     270.317460
# Name: Calories, dtype: float64

# %% [markdown]
# -- As size increases Calories increases.

# %%
x3 = df.groupby(['Milk'])['Calories'].mean().sort_values()
x3
# Out:
# Milk
# Nonfat Milk    189.506173
# Soymilk        207.692308
# 2% Milk        218.000000
# Whole Milk     289.333333
# Name: Calories, dtype: float64

# %% [markdown]
# -- There is no much difference between Nonfat Milk, Soymilk, 2% Milk.
# -- Whole Milk has significant difference for Calories.
# -- But needs to be verifie with Hypothesis Testing.

# %%
x4 = df.groupby(['Category'])['Calories'].mean().sort_values()
x4
# Out:
# Category
# Coffee                                4.250000
# Shaken Iced Beverages               114.444444
# Classic Espresso Drinks             140.172414
# Frappuccino Light Blended Coffee    162.500000
# Tazo Tea Drinks                     177.307692
# Frappuccino Blended Creme           248.888889
# Signature Espresso Drinks           250.000000
# Frappuccino Blended Coffee          276.944444
# Smoothies                           282.222222
# Name: Calories, dtype: float64

# %%
plt.plot(x2);
plt.xlabel('Size')
plt.ylabel('Calories')
plt.title('Size vs Calories')
# Out:
# Text(0.5, 1.0, 'Size vs Calories')

# %%
plt.plot(x3);
plt.xlabel('Milk Type')
plt.ylabel('Calories')
plt.title('Milk Type vs Calories')
# Out:
# Text(0.5, 1.0, 'Milk Type vs Calories')

# %%
plt.plot(x4)
plt.xlabel('Category')
plt.ylabel('Calories')
plt.title('Category vs Calories')
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#                   Category       Beverage    Size         Milk  Calories  \
# 0                   Coffee  Brewed Coffee   Short          NaN         3
# 1                   Coffee  Brewed Coffee    Tall          NaN         4
# 2                   Coffee  Brewed Coffee  Grande          NaN         5
# 3                   Coffee  Brewed Coffee   Venti          NaN         5
# 4  Classic Espresso Drinks    Caffe Latte   Short  Nonfat Milk        70
#
#    TotalFat  TransFat  SaturatedFat  Sodium  TotalCarb  Cholesterol  \
# 0       0.1       0.0           0.0       0          5            0
# 1       0.1       0.0           0.0       0         10            0
# 2       0.1       0.0           0.0       0         10            0
# 3       0.1       0.0           0.0       0         10            0
# 4       0.1       0.1           0.0       5         75           10
#
#    DietaryFibre  Sugars  Protein
# 0             0       0      0.3
# 1             0       0      0.5
# ...

# %%
sns.boxplot(x = df['Size'], y = df['Calories'])
# Out:
# <Axes: xlabel='Size', ylabel='Calories'>

# %%
sns.boxplot(x = df['Milk'], y = df['Calories'])
# Out:
# <Axes: xlabel='Milk', ylabel='Calories'>

# %%
y1 = np.percentile(df.loc[df['Milk']=='Nonfat Milk', 'Calories'], [100])
df.loc[df[['Calories']]>=y1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 2
#       1 y1 = np.percentile(df.loc[df['Milk']=='Nonfat Milk', 'Calories'], [100])
# ----> 2 df.loc[df[['Calories']]>=y1]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1380, in _LocIndexer._getitem_axis(self, key, axis)
#    1378 if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
# -> 1380         raise ValueError("Cannot index with multidimensional key")
#    1382     return self._getitem_iterable(key, axis=axis)
# ...

# %%
sns.boxplot(x = df['Category'], y = df['Calories'])
plt.xticks(rotation=90);
